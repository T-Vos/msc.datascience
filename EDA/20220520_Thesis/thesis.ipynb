# %%
import pandas as pd

polity = pd.read_csv('./polity4.csv')

# %%
polity.head(10)
# Out:
#    Unnamed: 0  cyear  ccode scode        country  year  flag  fragment  democ  \
# 0           1  21800      2   USA  United States  1800     0       NaN      7
# 1           2  21801      2   USA  United States  1801     0       NaN      7
# 2           3  21802      2   USA  United States  1802     0       NaN      7
# 3           4  21803      2   USA  United States  1803     0       NaN      7
# 4           5  21804      2   USA  United States  1804     0       NaN      7
# 5           6  21805      2   USA  United States  1805     0       NaN      7
# 6           7  21806      2   USA  United States  1806     0       NaN      7
# 7           8  21807      2   USA  United States  1807     0       NaN      7
# 8           9  21808      2   USA  United States  1808     0       NaN      7
# 9          10  21809      2   USA  United States  1809     0       NaN      9
#
#    autoc  ...  eprec  interim   byear  bdate  bprec  post  change   d3  sf  \
# ...
