# %%
import pandas as pd

def read_FH_AllData():
    return pd.read_excel("../../../Data/FreedomHouse/All_data_FIW_2013-2022.xlsx", sheet_name=1, header=1, engine='openpyxl')
# Out:
#      Country/Territory       Region C/T  Edition Status  PR rating  CL rating  \
# 0             Abkhazia      Eurasia   t     2022     PF          5          5
# 1          Afghanistan         Asia   c     2022     NF          7          6
# 2              Albania       Europe   c     2022     PF          3          3
# 3              Algeria       Africa   c     2022     NF          6          5
# 4              Andorra       Europe   c     2022      F          1          1
# ...                ...          ...  ..      ...    ...        ...        ...
# 2090         West Bank  Middle East   t     2013     NF          6          5
# 2091    Western Sahara       Africa   t     2013     NF          7          7
# 2092             Yemen  Middle East   c     2013     NF          6          6
# 2093            Zambia       Africa   c     2013     PF          3          4
# 2094          Zimbabwe       Africa   c     2013     NF          6          6
#
# ...

# %%
import pandas as pd

def read_FH_DemBool():
    electoralDemocracyBool = pd.read_excel("../../../Data/FreedomHouse/List_of_Electoral_Democracies_FIW22.xlsx", sheet_name=0, header=1, engine='openpyxl')
    electoralDemocracyBool = electoralDemocracyBool.iloc[:, :2]
    d = {'Yes': True, 'No': False}
    electoralDemocracyBool['Electoral Democracy Designation in FIW 2022'] = electoralDemocracyBool['Electoral Democracy Designation in FIW 2022'].map(d)
    return electoralDemocracyBool

read_FH_DemBool()
# Out:
#          Country  Electoral Democracy Designation in FIW 2022
# 0    Afghanistan                                        False
# 1        Albania                                         True
# 2        Algeria                                        False
# 3        Andorra                                         True
# 4         Angola                                        False
# ..           ...                                          ...
# 190    Venezuela                                        False
# 191      Vietnam                                        False
# 192        Yemen                                        False
# 193       Zambia                                        False
# 194     Zimbabwe                                        False
#
# [195 rows x 2 columns]

# %%
import pandas as pd
vdem = pd.read_csv("../../Data/Country_Year_V-Dem_Core_CSV_v11/V-Dem-CY-Core-v11.csv")

# %%
vdem.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c3047914f8d> in <module>
# ----> 1 vdem.info()
#
# NameError: name 'vdem' is not defined

# %%
vdem.head(10)
# Out:
#   country_name country_text_id  country_id  year historical_date  project  \
# 0       Mexico             MEX           3  1789      1789-12-31        1
# 1       Mexico             MEX           3  1790      1790-12-31        1
# 2       Mexico             MEX           3  1791      1791-12-31        1
# 3       Mexico             MEX           3  1792      1792-12-31        1
# 4       Mexico             MEX           3  1793      1793-12-31        1
# 5       Mexico             MEX           3  1794      1794-12-31        1
# 6       Mexico             MEX           3  1795      1795-12-31        1
# 7       Mexico             MEX           3  1796      1796-12-31        1
# 8       Mexico             MEX           3  1797      1797-12-31        1
# 9       Mexico             MEX           3  1798      1798-12-31        1
#
#    historical                  histname  codingstart  codingend  ...  \
# 0           1  Viceroyalty of New Spain         1789       2020  ...
# ...

# %%
vdem['v2xme_altinf_sd'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>
